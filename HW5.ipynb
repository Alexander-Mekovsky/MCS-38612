# %%
import os
import math

# %%
#!pip install graphviz
from graphviz import Digraph

# %%
def get_label(longname):
    filename = os.path.basename(longname)
    return filename if len(filename) <= 10 else filename[:7] + "..."

def get_rel_paths(here_path, root_path):
    here_path = os.path.abspath(here_path)
    root_path = os.path.abspath(root_path)
    if here_path == root_path:
        return ('..', '.')
    rel_to_here = os.path.relpath(here_path, root_path)
    parent_dir = os.path.dirname(here_path)
    if parent_dir == root_path:
        return ('.', rel_to_here)
    rel_to_parent = os.path.basename(parent_dir)
    return (rel_to_parent, rel_to_here)

def remove_excluded_subdirs(dir_list):
    """
    For os.path.walk(), we can restrict the branches that get traversed by changing
    the list which walk() returns as 'subdirs'.  Remember that when we are editing
    that list, we are actually changing the memory representation inside the walk()
    generator, so the semantics are a little tricky.  For example, we can't simultaneously
    loop over the list and edit it.  I'll give you a working function for this task
    to avoid confusion.
    
    This function removes 'reveal.js', '.git', and anything starting with '_' from the list.
    """
    more_names_to_remove = [elt for elt in dir_list if elt.startswith('_')][:]
    for nm in ['reveal.js', '.git'] + more_names_to_remove:
        if nm in dir_list:
            dir_list.remove(nm)

def show_this_leaf(nm):
    if nm[0] == '.':
        return False
    if nm[0] == '_':
        return False
    return True

class Node():
    def __init__(self, parent_node, name):
        """
        parent_node should be the Node instance of the parent.
        
        name is a long name, like a full relative path.  It needs to be
        unique for all nodes in the tree.
        
        Note how we make a connection to the parent node when this node is created.
        """
        self.parent = parent_node
        if self.parent is not None:
            self.parent._add_kid(self)
        self.name = name
        self.label = get_label(self.name)
        self.kids = []
        self.descendant_count = 0
    def _add_kid(self, kid_node):
        self.kids.append(kid_node)
        self.descendant_count += 1
    def add_descendant_to_all_ancestors(self):
        self.descendant_count += 1
        if self.parent:
            self.parent.add_descendant_to_all_ancestors()

    def write_node(self, indent=0):
        shape = 'rectangle' if not self.kids else 'ellipse'
        color = 'lightgray'
        if self.name.endswith(('.png', '.jpg', 'svg')):
            color = 'blue'
        print(f'{indent*" "}"{self.name}" [label="{self.label}", shape={shape}, style=filled, fillcolor={color}];')
    def traverse_node_defs(self, indent=0):
        """
        Write the DOT code that defines this Node and all its descendants.
        
        Here and in traverse_edge_defs(), 'indent' just helps with formatting
        when writing out the DOT code.
        """
        self.write_node(indent=indent)
        for kid in self.kids:
            kid.traverse_node_defs(indent+4)
    def write_incoming_edge(self, this_parent, indent=0):
        penwidth = max(1, int(math.sqrt(self.descendant_count)))
        print(f'{indent*" "}"{this_parent.name}" -> "{self.name}" [penwidth={penwidth}];')
    def traverse_edge_defs(self, indent=0):
        """
        Write the DOT code that defines the incoming edges for this Node and
        all its descendants.
        
        Here and in traverse_node_defs(), 'indent' just helps with formatting
        when writing out the DOT code.
        """
        for kid in self.kids:
            kid.write_incoming_edge(self, indent=indent+4)
            kid.traverse_edge_defs(indent+4)


# Maintain a dictionary of Nodes so that we can find them by name.  Use
# paths relative to the root as keys- so the very first key is just '.'
nodes = {}
root_path = r'C:\Users\ajmek\OneDrive\Documents\GitHub\CMU-MS-DAS-Vis-S25\docs'
root_node = Node(None, '.')
nodes['.'] = root_node

# Walk the tree
for dirname, subdirs, files in os.walk(root_path):
    remove_excluded_subdirs(subdirs)
    rel_dir_path, rel_path = get_rel_paths(dirname, root_path)
    if rel_path in nodes:
        # This happens on the very first node
        dir_node = nodes[rel_path]
    else:
        assert rel_dir_path in nodes
        dir_node= Node(nodes[rel_dir_path], rel_path)
        nodes[rel_path] = dir_node

    # Add nodes for all the children of this dir
    for file in files:
        if show_this_leaf(file):
            full_path = os.path.join(dirname, file)
            ignore_this, rel_path = get_rel_paths(full_path, root_path)
            #print(f"Creating node for: {rel_path}")
            this_node = Node(dir_node, rel_path)
            nodes[rel_path] = this_node

# Calculate number of descendants for all nodes
for node in nodes:
    nodes[node].add_descendant_to_all_ancestors()

# Write out the Dot code
print("digraph {")
root_node.traverse_node_defs()
root_node.traverse_edge_defs()
print("}")
# Out:
# digraph {
# "." [label=".", shape=ellipse, style=filled, fillcolor=lightgray];
#     "assignment_ggplot.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_ggplot_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_ipywidgets.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_ipywidgets_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_maps.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_maps_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_matplotlib.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_matplotlib_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_node_edge_graphs.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_node_edge_graphs_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_seaborn.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_seaborn_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_visit_movie.html" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "assignment_visit_movie_body.md" [label="assignm...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "course_intro.html" [label="course_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "course_intro_body.md" [label="course_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "dashboards.html" [label="dashboa...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "dashboards_body.md" [label="dashboa...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "data_manifolds.html" [label="data_ma...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "data_manifolds_body.md" [label="data_ma...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "git_and_github.html" [label="git_and...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "git_and_github_body.md" [label="git_and...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "grammar_of_graphics.html" [label="grammar...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "grammar_of_graphics_body.md" [label="grammar...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "graphs_with_nodes_and_edges.html" [label="graphs_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "graphs_with_nodes_and_edges_body.md" [label="graphs_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "idioms_for_statistics.html" [label="idioms_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "idioms_for_statistics_body.md" [label="idioms_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "index.md" [label="index.md", shape=rectangle, style=filled, fillcolor=lightgray];
#     "ipywidgets_intro.html" [label="ipywidg...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "ipywidgets_intro_body.md" [label="ipywidg...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "maps.html" [label="maps.html", shape=rectangle, style=filled, fillcolor=lightgray];
#     "maps_body.md" [label="maps_bo...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "marching_squares.html" [label="marchin...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "marching_squares_body.md" [label="marchin...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "my_notes.html" [label="my_note...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "my_notes_body.md" [label="my_note...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "now_we_need_a_web_server.html" [label="now_we_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "now_we_need_a_web_server_body.md" [label="now_we_...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "overview.md" [label="overvie...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "sci_vis_algorithms.html" [label="sci_vis...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "sci_vis_algorithms_body.md" [label="sci_vis...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "thinking_about_coordinates.html" [label="thinkin...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "thinking_about_coordinates_body.md" [label="thinkin...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "using_color.html" [label="using_c...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "using_color_body.md" [label="using_c...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "visit.html" [label="visit.html", shape=rectangle, style=filled, fillcolor=lightgray];
#     "visit_body.md" [label="visit_b...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "welcome_to_d3.html" [label="welcome...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "welcome_to_d3_body.md" [label="welcome...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "why_vis.html" [label="why_vis...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "why_vis_body.md" [label="why_vis...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "you_need_multiple_venvs.html" [label="you_nee...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "you_need_multiple_venvs_body.md" [label="you_nee...", shape=rectangle, style=filled, fillcolor=lightgray];
#     "css" [label="css", shape=ellipse, style=filled, fillcolor=lightgray];
#         "css\white.css" [label="white.css", shape=rectangle, style=filled, fillcolor=lightgray];
#     "images" [label="images", shape=ellipse, style=filled, fillcolor=lightgray];
#         "images\10.1371_journal.pone.0113838_fig_5.png" [label="10.1371...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\800px-Australian_Census_2011_demographic_map_-_Australia_by_SLA_-_BCP_field_2715_Christianity_Anglican_Persons.svg.png" [label="800px-A...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\800px-Equirectangular_projection_SW.jpg" [label="800px-E...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\abscomb_by_seaborn.png" [label="abscomb...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\allegheny_census_tracts.png" [label="alleghe...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\allegheny_census_tracts_zoomed.png" [label="alleghe...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\browser_server_kernel.png" [label="browser...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\browser_server_kernel_widget.png" [label="browser...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\colin_3d_isosurfaces.png" [label="colin_3...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\colin_brain_contour_plot.png" [label="colin_b...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\color_lookup_alg.png" [label="color_l...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\compact_graphs_2x.png" [label="compact...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\components_of_visit.png" [label="compone...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\cube_of_cubes.png" [label="cube_of...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\dashboard_all_subj.png" [label="dashboa...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\dashboard_qual_tbl.png" [label="dashboa...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\dashboard_status_fig.png" [label="dashboa...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\dashboard_two_subj.png" [label="dashboa...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\draw_slice_z_with_slider.png" [label="draw_sl...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\ECEF_ENU_Longitude_Latitude_relationships.svg" [label="ECEF_EN...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\elven_assassin_screencap.png" [label="elven_a...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\example_graph_1.svg" [label="example...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\example_graph_2.svg" [label="example...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\example_graph_3.svg" [label="example...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\example_graph_4.svg" [label="example...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\fibers_on_manifold.png" [label="fibers_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\fibers_on_manifold_gradient.png" [label="fibers_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\find_the_curved_line.jpg" [label="find_th...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\git_history_graph.png" [label="git_his...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\git_index_state.png" [label="git_ind...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\graphviz_assignment_example.png" [label="graphvi...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\graphviz_test.png" [label="graphvi...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\hanrahan_ray_marching.png" [label="hanraha...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\Ishihara-test---numerals.gif" [label="Ishihar...", shape=rectangle, style=filled, fillcolor=lightgray];
#         "images\isosurface_colin_1.png" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\isosurface_colin_1_zoom.png" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\isosurface_colin_2.png" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\isosurface_colin_2_zoom.png" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\isosurface_fluid_temp.jpg" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\isosurface_fluid_vorticity.jpg" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\isosurface_show_triangles.png" [label="isosurf...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\joel_fft.png" [label="joel_ff...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\joel_real.png" [label="joel_re...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\joel_real_and_fft.png" [label="joel_re...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\lighted_footprint.jpg" [label="lighted...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_cubes_4and4_c10.jpg" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_cubes_4and4_c11.jpg" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_cubes_4and4_c8.jpg" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_cubes_4and4_c9.jpg" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_cubes_cases_c3_c19.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_2a.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_2b.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_2_both.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_3.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_4_rule_1.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_4_rule_2.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_case_one.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\marching_squares_putting_cells_together.png" [label="marchin...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\mario_motion_illusion.gif" [label="mario_m...", shape=rectangle, style=filled, fillcolor=lightgray];
#         "images\Minard.png" [label="Minard.png", shape=rectangle, style=filled, fillcolor=blue];
#         "images\minard_with_plotnine.png" [label="minard_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\More_Complete_Flask_Application.svg" [label="More_Co...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\myproj_graphviz_page.png" [label="myproj_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\PA_FIPS.png" [label="PA_FIPS...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\PA_FIPS_zoomed.png" [label="PA_FIPS...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\pa_travel_loop.png" [label="pa_trav...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\pgh_topo_cmap_contoured.png" [label="pgh_top...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\pgh_topo_cmap_difference.png" [label="pgh_top...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\pgh_topo_cmap_rainbow.png" [label="pgh_top...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\pgh_topo_cmap_viridis.png" [label="pgh_top...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\pgh_topo_relief.png" [label="pgh_top...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\preconscious_vs_conscious_bandwidths.png" [label="precons...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\ProbSnowGE08.jpg" [label="ProbSno...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\ScagnosticsExampleSplom.svg" [label="Scagnos...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\simple_color_mapped_image.png" [label="simple_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\simple_contour_plot.png" [label="simple_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\Simple_Flask_Application.svg" [label="Simple_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\simple_graph_svg_example.png" [label="simple_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\simple_stacked_bar_chart.png" [label="simple_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\simple_stacked_line_graph.png" [label="simple_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\SnowAmt10Prcntl.jpg" [label="SnowAmt...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\SnowAmt90Prcntl.jpg" [label="SnowAmt...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\stacked_bar_charts_showing_changes.png" [label="stacked...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\StormTotalSnowWeb.jpg" [label="StormTo...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\Streamlines.png" [label="Streaml...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\Streamlines2.png" [label="Streaml...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\streamlit_graphviz_app.png" [label="streaml...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\time_courses_with_iqr.png" [label="time_co...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\Time_Curve_Of_A_Statistical_Range.png" [label="Time_Cu...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\transformation-Mercator-navigation-projection.jpg" [label="transfo...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\VaccineChoice.png" [label="Vaccine...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\VaccineChoiceDevFigure.png" [label="Vaccine...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\VaccineChoiceManuscriptCode.png" [label="Vaccine...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\VaccineChoiceManuscriptCode2.png" [label="Vaccine...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\VaccineChoicePubFigure.png" [label="Vaccine...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\visit_anim_frame_0.png" [label="visit_a...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\visual_processing.png" [label="visual_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\vis_pipeline.png" [label="vis_pip...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\volume_rendered_colin.png" [label="volume_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\volume_rendering_color_table.png" [label="volume_...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\world_reproj_mercator.png" [label="world_r...", shape=rectangle, style=filled, fillcolor=blue];
#         "images\xkcd_git.png" [label="xkcd_gi...", shape=rectangle, style=filled, fillcolor=blue];
#     "." -> "assignment_ggplot.html" [penwidth=1];
#     "." -> "assignment_ggplot_body.md" [penwidth=1];
#     "." -> "assignment_ipywidgets.html" [penwidth=1];
#     "." -> "assignment_ipywidgets_body.md" [penwidth=1];
#     "." -> "assignment_maps.html" [penwidth=1];
#     "." -> "assignment_maps_body.md" [penwidth=1];
#     "." -> "assignment_matplotlib.html" [penwidth=1];
#     "." -> "assignment_matplotlib_body.md" [penwidth=1];
#     "." -> "assignment_node_edge_graphs.html" [penwidth=1];
#     "." -> "assignment_node_edge_graphs_body.md" [penwidth=1];
#     "." -> "assignment_seaborn.html" [penwidth=1];
#     "." -> "assignment_seaborn_body.md" [penwidth=1];
#     "." -> "assignment_visit_movie.html" [penwidth=1];
#     "." -> "assignment_visit_movie_body.md" [penwidth=1];
#     "." -> "course_intro.html" [penwidth=1];
#     "." -> "course_intro_body.md" [penwidth=1];
#     "." -> "dashboards.html" [penwidth=1];
#     "." -> "dashboards_body.md" [penwidth=1];
#     "." -> "data_manifolds.html" [penwidth=1];
#     "." -> "data_manifolds_body.md" [penwidth=1];
#     "." -> "git_and_github.html" [penwidth=1];
#     "." -> "git_and_github_body.md" [penwidth=1];
#     "." -> "grammar_of_graphics.html" [penwidth=1];
#     "." -> "grammar_of_graphics_body.md" [penwidth=1];
#     "." -> "graphs_with_nodes_and_edges.html" [penwidth=1];
#     "." -> "graphs_with_nodes_and_edges_body.md" [penwidth=1];
#     "." -> "idioms_for_statistics.html" [penwidth=1];
#     "." -> "idioms_for_statistics_body.md" [penwidth=1];
#     "." -> "index.md" [penwidth=1];
#     "." -> "ipywidgets_intro.html" [penwidth=1];
#     "." -> "ipywidgets_intro_body.md" [penwidth=1];
#     "." -> "maps.html" [penwidth=1];
#     "." -> "maps_body.md" [penwidth=1];
#     "." -> "marching_squares.html" [penwidth=1];
#     "." -> "marching_squares_body.md" [penwidth=1];
#     "." -> "my_notes.html" [penwidth=1];
#     "." -> "my_notes_body.md" [penwidth=1];
#     "." -> "now_we_need_a_web_server.html" [penwidth=1];
#     "." -> "now_we_need_a_web_server_body.md" [penwidth=1];
#     "." -> "overview.md" [penwidth=1];
#     "." -> "sci_vis_algorithms.html" [penwidth=1];
#     "." -> "sci_vis_algorithms_body.md" [penwidth=1];
#     "." -> "thinking_about_coordinates.html" [penwidth=1];
#     "." -> "thinking_about_coordinates_body.md" [penwidth=1];
#     "." -> "using_color.html" [penwidth=1];
#     "." -> "using_color_body.md" [penwidth=1];
#     "." -> "visit.html" [penwidth=1];
#     "." -> "visit_body.md" [penwidth=1];
#     "." -> "welcome_to_d3.html" [penwidth=1];
#     "." -> "welcome_to_d3_body.md" [penwidth=1];
#     "." -> "why_vis.html" [penwidth=1];
#     "." -> "why_vis_body.md" [penwidth=1];
#     "." -> "you_need_multiple_venvs.html" [penwidth=1];
#     "." -> "you_need_multiple_venvs_body.md" [penwidth=1];
#     "." -> "css" [penwidth=1];
#         "css" -> "css\white.css" [penwidth=1];
#     "." -> "images" [penwidth=14];
#         "images" -> "images\10.1371_journal.pone.0113838_fig_5.png" [penwidth=1];
#         "images" -> "images\800px-Australian_Census_2011_demographic_map_-_Australia_by_SLA_-_BCP_field_2715_Christianity_Anglican_Persons.svg.png" [penwidth=1];
#         "images" -> "images\800px-Equirectangular_projection_SW.jpg" [penwidth=1];
#         "images" -> "images\abscomb_by_seaborn.png" [penwidth=1];
#         "images" -> "images\allegheny_census_tracts.png" [penwidth=1];
#         "images" -> "images\allegheny_census_tracts_zoomed.png" [penwidth=1];
#         "images" -> "images\browser_server_kernel.png" [penwidth=1];
#         "images" -> "images\browser_server_kernel_widget.png" [penwidth=1];
#         "images" -> "images\colin_3d_isosurfaces.png" [penwidth=1];
#         "images" -> "images\colin_brain_contour_plot.png" [penwidth=1];
#         "images" -> "images\color_lookup_alg.png" [penwidth=1];
#         "images" -> "images\compact_graphs_2x.png" [penwidth=1];
#         "images" -> "images\components_of_visit.png" [penwidth=1];
#         "images" -> "images\cube_of_cubes.png" [penwidth=1];
#         "images" -> "images\dashboard_all_subj.png" [penwidth=1];
#         "images" -> "images\dashboard_qual_tbl.png" [penwidth=1];
#         "images" -> "images\dashboard_status_fig.png" [penwidth=1];
#         "images" -> "images\dashboard_two_subj.png" [penwidth=1];
#         "images" -> "images\draw_slice_z_with_slider.png" [penwidth=1];
#         "images" -> "images\ECEF_ENU_Longitude_Latitude_relationships.svg" [penwidth=1];
#         "images" -> "images\elven_assassin_screencap.png" [penwidth=1];
#         "images" -> "images\example_graph_1.svg" [penwidth=1];
#         "images" -> "images\example_graph_2.svg" [penwidth=1];
#         "images" -> "images\example_graph_3.svg" [penwidth=1];
#         "images" -> "images\example_graph_4.svg" [penwidth=1];
#         "images" -> "images\fibers_on_manifold.png" [penwidth=1];
#         "images" -> "images\fibers_on_manifold_gradient.png" [penwidth=1];
#         "images" -> "images\find_the_curved_line.jpg" [penwidth=1];
#         "images" -> "images\git_history_graph.png" [penwidth=1];
#         "images" -> "images\git_index_state.png" [penwidth=1];
#         "images" -> "images\graphviz_assignment_example.png" [penwidth=1];
#         "images" -> "images\graphviz_test.png" [penwidth=1];
#         "images" -> "images\hanrahan_ray_marching.png" [penwidth=1];
#         "images" -> "images\Ishihara-test---numerals.gif" [penwidth=1];
#         "images" -> "images\isosurface_colin_1.png" [penwidth=1];
#         "images" -> "images\isosurface_colin_1_zoom.png" [penwidth=1];
#         "images" -> "images\isosurface_colin_2.png" [penwidth=1];
#         "images" -> "images\isosurface_colin_2_zoom.png" [penwidth=1];
#         "images" -> "images\isosurface_fluid_temp.jpg" [penwidth=1];
#         "images" -> "images\isosurface_fluid_vorticity.jpg" [penwidth=1];
#         "images" -> "images\isosurface_show_triangles.png" [penwidth=1];
#         "images" -> "images\joel_fft.png" [penwidth=1];
#         "images" -> "images\joel_real.png" [penwidth=1];
#         "images" -> "images\joel_real_and_fft.png" [penwidth=1];
#         "images" -> "images\lighted_footprint.jpg" [penwidth=1];
#         "images" -> "images\marching_cubes_4and4_c10.jpg" [penwidth=1];
#         "images" -> "images\marching_cubes_4and4_c11.jpg" [penwidth=1];
#         "images" -> "images\marching_cubes_4and4_c8.jpg" [penwidth=1];
#         "images" -> "images\marching_cubes_4and4_c9.jpg" [penwidth=1];
#         "images" -> "images\marching_cubes_cases_c3_c19.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_2a.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_2b.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_2_both.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_3.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_4_rule_1.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_4_rule_2.png" [penwidth=1];
#         "images" -> "images\marching_squares_case_one.png" [penwidth=1];
#         "images" -> "images\marching_squares_putting_cells_together.png" [penwidth=1];
#         "images" -> "images\mario_motion_illusion.gif" [penwidth=1];
#         "images" -> "images\Minard.png" [penwidth=1];
#         "images" -> "images\minard_with_plotnine.png" [penwidth=1];
#         "images" -> "images\More_Complete_Flask_Application.svg" [penwidth=1];
#         "images" -> "images\myproj_graphviz_page.png" [penwidth=1];
#         "images" -> "images\PA_FIPS.png" [penwidth=1];
#         "images" -> "images\PA_FIPS_zoomed.png" [penwidth=1];
#         "images" -> "images\pa_travel_loop.png" [penwidth=1];
#         "images" -> "images\pgh_topo_cmap_contoured.png" [penwidth=1];
#         "images" -> "images\pgh_topo_cmap_difference.png" [penwidth=1];
#         "images" -> "images\pgh_topo_cmap_rainbow.png" [penwidth=1];
#         "images" -> "images\pgh_topo_cmap_viridis.png" [penwidth=1];
#         "images" -> "images\pgh_topo_relief.png" [penwidth=1];
#         "images" -> "images\preconscious_vs_conscious_bandwidths.png" [penwidth=1];
#         "images" -> "images\ProbSnowGE08.jpg" [penwidth=1];
#         "images" -> "images\ScagnosticsExampleSplom.svg" [penwidth=1];
#         "images" -> "images\simple_color_mapped_image.png" [penwidth=1];
#         "images" -> "images\simple_contour_plot.png" [penwidth=1];
#         "images" -> "images\Simple_Flask_Application.svg" [penwidth=1];
#         "images" -> "images\simple_graph_svg_example.png" [penwidth=1];
#         "images" -> "images\simple_stacked_bar_chart.png" [penwidth=1];
#         "images" -> "images\simple_stacked_line_graph.png" [penwidth=1];
#         "images" -> "images\SnowAmt10Prcntl.jpg" [penwidth=1];
#         "images" -> "images\SnowAmt90Prcntl.jpg" [penwidth=1];
#         "images" -> "images\stacked_bar_charts_showing_changes.png" [penwidth=1];
#         "images" -> "images\StormTotalSnowWeb.jpg" [penwidth=1];
#         "images" -> "images\Streamlines.png" [penwidth=1];
#         "images" -> "images\Streamlines2.png" [penwidth=1];
#         "images" -> "images\streamlit_graphviz_app.png" [penwidth=1];
#         "images" -> "images\time_courses_with_iqr.png" [penwidth=1];
#         "images" -> "images\Time_Curve_Of_A_Statistical_Range.png" [penwidth=1];
#         "images" -> "images\transformation-Mercator-navigation-projection.jpg" [penwidth=1];
#         "images" -> "images\VaccineChoice.png" [penwidth=1];
#         "images" -> "images\VaccineChoiceDevFigure.png" [penwidth=1];
#         "images" -> "images\VaccineChoiceManuscriptCode.png" [penwidth=1];
#         "images" -> "images\VaccineChoiceManuscriptCode2.png" [penwidth=1];
#         "images" -> "images\VaccineChoicePubFigure.png" [penwidth=1];
#         "images" -> "images\visit_anim_frame_0.png" [penwidth=1];
#         "images" -> "images\visual_processing.png" [penwidth=1];
#         "images" -> "images\vis_pipeline.png" [penwidth=1];
#         "images" -> "images\volume_rendered_colin.png" [penwidth=1];
#         "images" -> "images\volume_rendering_color_table.png" [penwidth=1];
#         "images" -> "images\world_reproj_mercator.png" [penwidth=1];
#         "images" -> "images\xkcd_git.png" [penwidth=1];
# }
